# %%
import json 
import boto3
import botocore
from model_setup import get_model_specs, get_model_run_file

# %%
# Get split lists
s3 = boto3.client("s3")
    
bucket = "w210-poverty-mapper"
directory_path = "modeling/data_splits/two_02_across_even/"

response = s3.list_objects(Bucket=bucket, Prefix="modeling/data_splits/two_02_across_even/", Delimiter="/")
directories = [x["Prefix"] for x in response["CommonPrefixes"]] 
split_names = [x.replace("modeling/data_splits/two_02_across_even/", "")[:-1] for x in directories]

# Get file list for replicate run
#replicate_names = [x for x in split_names if "10k_1d" in x]
#replicate_names 

# Get file list for leave out within 10k, 5k, and 50d
#distances = [x for x in split_names if "2_5k" not in x and "1d" not in x and "100d" not in x]
#leave_out_within_5k_10k_50d = [x for x in distances if x.startswith("leave") or x.startswith("within")]
#leave_out_within_5k_10k_50d

# Get file list for leave out within 5k 50d
#distances = [x for x in split_names  if "2_5k" not in x and "10k" not in x and "1d" not in x and "100d" not in x]
#leave_out_within_5k_50d = [x for x in distances if x.startswith("leave") or x.startswith("within")]
#leave_out_within_5k_50d

# Get file list for within 10k and 5k
#distances = [x for x in split_names if "2_5k" not in x and "1d" not in x and "100d" not in x]
#within_5k_10k_50d = [x for x in distances if x.startswith("within")]
#within_5k_10k_50d

# Get file list for within 5k and 50d
#distances = [x for x in split_names if "2_5k" not in x and "10k" not in x and "1d" not in x and "100d" not in x]
#within_5k_50d = [x for x in distances if x.startswith("within")]
#within_5k_50d

# Get file list for leave-one-out 5k and 50d
#distances = [x for x in split_names if "2_5k" not in x and "10k" not in x and "1d" not in x and "100d" not in x]
#across_5k_50d = [x for x in distances if x.startswith("leave")]
#across_5k_50d

# Get file list for similar geographies (leave-one-out)
#split_names
# distances = [x for x in split_names if "_2_5k" not in x and "10k" not in x and "1d" not in x and "100d" not in x]
# similar_geos = [x for x in distances if x.startswith("south_central_leave_one_out_v3") or x.startswith("south_central_leave_one_out_v4") or x.startswith("southeast_leave_one_out")]
# similar_geos

# Get file list for similar geographies (cross-country)
split_names
distances = [x for x in split_names if "_2_5k" not in x and "10k" not in x and "1d" not in x and "100d" not in x]
similar_geos_across = [x for x in distances if x.startswith("south_central_cross") or x.startswith("southeast_cross")]
similar_geos_across
# Out:
# ['south_central_cross_country_v1_5k_50d',
#  'south_central_cross_country_v2_5k_50d',
#  'south_central_cross_country_v3_5k_50d',
#  'southeast_cross_country_v1_5k_50d']

# %%
# Get test model specs and run file
#s3_filename = "test_model_run"
#split_name_list = ["leave_one_out_bangladesh_10k_100d"]
#pretrained_list = ["resnet18", "resnet50"]
#freeze_layers_list = ["yes", "no"]
#epoch_list = [10, 20]
#learning_rate_list = [0.001, 0.0001]
#gamma_list = [0.1, 0.2]
#step_size_list = [4]
#batch_size_list = [8]
#num_workers_list = [4]

#get_model_specs(split_name_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)
#get_model_run_file(s3_filename, split_name_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# Get replicate previous model specs
#s3_filename = "replicate_previous"
#split_name_list = replicate_names
#num_classes_list = [5]
#bin_method_list = ["across"]
#pretrained_list = ["resnet18"]
#freeze_layers_list = ["yes", "no"]
#epoch_list = [10, 20]
#learning_rate_list = [0.001, 0.0001]
#gamma_list = [0.1]
#step_size_list = [5, 10]
#batch_size_list = [448]
#num_workers_list = [8]

#get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 1
# s3_filename = "replicate_previous_1"
# split_name_list = replicate_names
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["yes"]
# epoch_list = [10]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [8]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 2
# s3_filename = "replicate_previous_2"
# split_name_list = replicate_names
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["yes"]
# epoch_list = [20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [8]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 3
# s3_filename = "replicate_previous_3"
# split_name_list = replicate_names
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [8]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 4
# s3_filename = "replicate_previous_4"
# split_name_list = replicate_names
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [8]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get threshold check model specs 
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 1
# s3_filename = "threshold_check_1"
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 2
# s3_filename = "threshold_check_2"
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["across"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get binary within 0.2 model specs
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [2]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 1
# s3_filename = "binary_within_1"
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [2]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Part 1
# s3_filename = "binary_within_2"
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [2]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get within country within bining specs
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within within part 1
# s3_filename = "within_country_within_binning_1"
# split_name_list = within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within within part 2
# s3_filename = "within_country_within_binning_2"
# split_name_list = within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within within part 3
# s3_filename = "within_country_within_binning_3"
# split_name_list = within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within within part 4
# s3_filename = "within_country_within_binning_4"
# split_name_list = within_5k_10k_50d
# num_classes_list = [5]
# bin_method_list = ["within"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# Get even sampling specs
# split_name_list = leave_out_within_5k_10k_50d
# num_classes_list = [2, 5]
# bin_method_list = ["within_even", "across_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 1
# s3_filename = "even_sampling_1"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 2
# s3_filename = "even_sampling_2"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 3
# s3_filename = "even_sampling_3"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [5]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 4
# s3_filename = "even_sampling_4"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [5]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 5
# s3_filename = "even_sampling_5"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 6
# s3_filename = "even_sampling_6"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 7
# s3_filename = "even_sampling_7"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [5]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Even samples part 8
# s3_filename = "even_sampling_8"
# split_name_list = leave_out_within_5k_50d
# num_classes_list = [5]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet18"]
# freeze_layers_list = ["no"]
# epoch_list = [10, 20]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [5, 10]
# batch_size_list = [448]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get MLP experiment files
# split_name_list = ["leave_one_out_bangladesh_5k_50d", "leave_one_out_nepal_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get MLP experiment files
# split_name_list = ["within_country_bangladesh_5k_50d", "within_country_nepal_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP experiment 1 
# s3_filename = "mlp_experiment_1"
# split_name_list = ["leave_one_out_bangladesh_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP experiment 2
# s3_filename = "mlp_experiment_2"
# split_name_list = ["leave_one_out_nepal_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP experiment 3
# s3_filename = "mlp_experiment_3"
# split_name_list = ["within_country_bangladesh_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP experiment 4
# s3_filename = "mlp_experiment_4"
# split_name_list = ["within_country_nepal_5k_50d"]
# num_classes_list = [2, 5]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP additional countries
# split_name_list = ["within_country_philippines_5k_50d", "within_country_tajikistan_5k_50d", "within_country_timor_leste_5k_50d"]
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP additional countries run file 1
# s3_filename = "mlp_additional_1"
# split_name_list = ["within_country_philippines_5k_50d"]
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP additional countries run file 2
# s3_filename = "mlp_additional_2"
# split_name_list = ["within_country_tajikistan_5k_50d"]
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # MLP additional countries run file 3
# s3_filename = "mlp_additional_3"
# split_name_list = ["within_country_timor_leste_5k_50d"]
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["yes"]
# epoch_list = [30, 50]
# learning_rate_list = [0.00015, 0.0001,  0.000015, 0.00001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get within unfrozen even sampling specs
# split_name_list = within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within unfrozen even sampling run file 1
# s3_filename = "within_unfrozen_even_1"
# split_name_list = within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Within unfrozen even sampling run file 2
# s3_filename = "within_unfrozen_even_2"
# split_name_list = within_5k_50d
# num_classes_list = [2]
# bin_method_list = ["within_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # # Get across unfrozen even sampling specs
# split_name_list = across_5k_50d
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Across unfrozen even sampling 1
# s3_filename = "across_unfrozen_even_1"
# split_name_list = across_5k_50d
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Across unfrozen even sampling 2
# s3_filename = "across_unfrozen_even_2"
# split_name_list = across_5k_50d
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get similar geography unfrozen even sampling specs
# split_name_list = similar_geos
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Similar geography unfrozen even sampling run 1
# s3_filename = "similar_geo_unfrozen_even_1"
# split_name_list = similar_geos
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Similar geography unfrozen even sampling run 2
# s3_filename = "similar_geo_unfrozen_even_2"
# split_name_list = similar_geos
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Get similar geography unfrozen even sampling specs
# split_name_list = similar_geos_across
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001, 0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_specs(split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Similar geography unfrozen even sampling cross-country 1
# s3_filename = "similar_geo_unfrozen_even_cross_country_1"
# split_name_list = similar_geos_across
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)

# %%
# # Similar geography unfrozen even sampling cross-country 2
# s3_filename = "similar_geo_unfrozen_even_cross_country_2"
# split_name_list = similar_geos_across
# num_classes_list = [2]
# bin_method_list = ["across_even"]
# pretrained_list = ["resnet50"]
# freeze_layers_list = ["no"]
# epoch_list = [20, 30]
# learning_rate_list = [0.0001]
# gamma_list = [0.1]
# step_size_list = [10]
# batch_size_list = [64]
# num_workers_list = [4]

# get_model_run_file(s3_filename, split_name_list, num_classes_list, bin_method_list, pretrained_list, freeze_layers_list, epoch_list, learning_rate_list, gamma_list, step_size_list, batch_size_list, num_workers_list)
