# %%
import pandas as pd

# %%
# Load combined training metrics
metrics = pd.read_csv("s3://w210-poverty-mapper/modeling/results/combined_results.csv")

# %%
metrics.head()
# Out:
#                         split_name  num_classes bin_method pretrained  \
# 0  leave_one_out_bangladesh_10k_1d            5     across   resnet18
# 1  leave_one_out_bangladesh_10k_1d            5     across   resnet18
# 2  leave_one_out_bangladesh_10k_1d            5     across   resnet18
# 3  leave_one_out_bangladesh_10k_1d            5     across   resnet18
# 4  leave_one_out_bangladesh_10k_1d            5     across   resnet18
#
#   freeze_layers  epochs  learning_rate  gamma  step_size  batch_size  ...  \
# 0            no      10         0.0001    0.1         10         448  ...
# 1            no      10         0.0001    0.1         10         448  ...
# 2            no      10         0.0001    0.1         10         448  ...
# 3            no      10         0.0001    0.1         10         448  ...
# 4            no      10         0.0001    0.1         10         448  ...
#
#    val_precision  val_recall  val_f1  test_precision  test_recall  test_f1  \
# 0            NaN         NaN     NaN             NaN          NaN      NaN
# 1            NaN         NaN     NaN             NaN          NaN      NaN
# 2            NaN         NaN     NaN             NaN          NaN      NaN
# 3            NaN         NaN     NaN             NaN          NaN      NaN
# 4            NaN         NaN     NaN             NaN          NaN      NaN
#
#                       split    split_group  max_val_f1  top_n_max_val_f1
# 0  leave_one_out_bangladesh  leave_one_out         NaN                 0
# 1  leave_one_out_bangladesh  leave_one_out         NaN                 0
# 2  leave_one_out_bangladesh  leave_one_out         NaN                 0
# 3  leave_one_out_bangladesh  leave_one_out         NaN                 0
# 4  leave_one_out_bangladesh  leave_one_out         NaN                 0
#
# [5 rows x 47 columns]

# %%
# Add country name column
metrics["country"] = metrics["split"].replace(regex=["within_country_", "leave_one_out_"], value="")

# %%
# Get unique countries
metrics["country"].unique()
# Out:
# array(['bangladesh', 'nepal', 'philippines', 'tajikistan', 'timor_leste',
#        'south_central_cross_country_v1', 'south_central_cross_country_v2',
#        'south_central_cross_country_v3', 'south_central_v1',
#        'south_central_v2', 'south_central_v3', 'south_central_v4',
#        'southeast_cross_country_v1', 'southeast_v1'], dtype=object)

# %%
# Add data threshold column (e.g. "5k_50d")
metrics["data_thresholds"] = metrics.apply(lambda row: "_".join(row["split_name"].split("_")[-2:]), axis=1)

# %%
# Print unique data thresholds
metrics["data_thresholds"].unique()
# Out:
# array(['10k_1d', '10k_50d', '5k_50d'], dtype=object)

# %%
# Print unique split groups
metrics["split_group"].unique()
# Out:
# array(['leave_one_out', 'similar geography', 'within_country'],
#       dtype=object)

# %%
# Keep relevant metrics
subset = metrics.loc[(metrics["num_classes"] == 2) & 
                     (metrics["data_thresholds"] == "5k_50d") & 
                     (metrics["freeze_layers"] == "no") &
                     metrics["bin_method"].isin(["within_even", "across_even"])]

# %%
# Print unique bin methods
subset["bin_method"].unique()
# Out:
# array(['across_even', 'within_even'], dtype=object)

# %%
# Add indicator for top val F1 by group
grouped = subset.groupby(["split", "id"])
grouped = grouped["val_f1"].max()
grouped = grouped.reset_index()
grouped = grouped.rename(columns={"val_f1": "max_val_f1_final"})

def get_top_n(col, in_name, out_name, k):
    values = sorted(col[in_name].tolist(), reverse=True)
    #print(len(values))
    thresh = values[min(k, len(values))-1]
    col[out_name] = col.apply(lambda row: 1 if row[in_name] >= thresh else 0, axis=1)
    return col

grouped = grouped.groupby(["split"]).apply(lambda x: get_top_n(x, "max_val_f1_final", "best_val_f1", 1))
joined = subset.merge(grouped, on=["split", "id"], how="outer")

# %%
# Prinr unique countries for best validation f1
joined[joined["best_val_f1"] == 1]["country"].unique()
# Out:
# array(['bangladesh', 'nepal', 'philippines', 'timor_leste',
#        'south_central_cross_country_v1', 'south_central_cross_country_v2',
#        'south_central_cross_country_v3', 'south_central_v3',
#        'south_central_v4', 'southeast_cross_country_v1', 'southeast_v1',
#        'tajikistan'], dtype=object)

# %%
# Print unique ids for best validation metric
joined[joined["best_val_f1"] == 1]["id"].unique()
# Out:
# array([ 44, 125, 210, 347, 391, 411, 413, 468, 470, 491, 510, 569, 671,
#        771, 861, 953])

# %%
# Keep best valiation metrics
joined_subset = joined.loc[(joined["best_val_f1"] == 1)]

# %%
# Sort by id and epoch
joined_subset = joined_subset.sort_values(by=["id", "epoch"])

# %%
# Keep single record for each country and model type (since there are multiple epochs)
joined_subset = joined_subset.drop_duplicates(subset=["id"], keep="first")

# %%
joined_subset
# Out:
#                                  split_name  num_classes   bin_method  \
# 70          leave_one_out_bangladesh_5k_50d            2  across_even
# 100              leave_one_out_nepal_5k_50d            2  across_even
# 220        leave_one_out_philippines_5k_50d            2  across_even
# 440        leave_one_out_timor_leste_5k_50d            2  across_even
# 540   south_central_cross_country_v1_5k_50d            2  across_even
# 640   south_central_cross_country_v2_5k_50d            2  across_even
# 700   south_central_cross_country_v3_5k_50d            2  across_even
# 870   south_central_leave_one_out_v3_5k_50d            2  across_even
# 920   south_central_leave_one_out_v4_5k_50d            2  across_even
# 1040      southeast_cross_country_v1_5k_50d            2  across_even
# 1120      southeast_leave_one_out_v1_5k_50d            2  across_even
# 1200       within_country_bangladesh_5k_50d            2  within_even
# 1340            within_country_nepal_5k_50d            2  within_even
# 1440      within_country_philippines_5k_50d            2  within_even
# 1500       within_country_tajikistan_5k_50d            2  within_even
# 1600      within_country_timor_leste_5k_50d            2  within_even
#
#      pretrained freeze_layers  epochs  learning_rate  gamma  step_size  \
# 70     resnet50            no      30         0.0010    0.1         10
# 100    resnet50            no      20         0.0001    0.1         10
# 220    resnet50            no      20         0.0010    0.1         10
# 440    resnet50            no      30         0.0001    0.1         10
# 540    resnet50            no      30         0.0001    0.1         10
# 640    resnet50            no      30         0.0001    0.1         10
# 700    resnet50            no      20         0.0001    0.1         10
# 870    resnet50            no      30         0.0010    0.1         10
# 920    resnet50            no      20         0.0010    0.1         10
# 1040   resnet50            no      30         0.0001    0.1         10
# 1120   resnet50            no      20         0.0010    0.1         10
# 1200   resnet50            no      20         0.0001    0.1         10
# 1340   resnet50            no      30         0.0001    0.1         10
# 1440   resnet50            no      30         0.0001    0.1         10
# 1500   resnet50            no      20         0.0001    0.1         10
# 1600   resnet50            no      20         0.0001    0.1         10
#
#       batch_size  ...  test_recall   test_f1                           split  \
# 70            64  ...     0.083945  0.147262        leave_one_out_bangladesh
# 100           64  ...     0.290323  0.289474             leave_one_out_nepal
# 220           64  ...     0.505376  0.106155       leave_one_out_philippines
# 440           64  ...     0.062189  0.108225       leave_one_out_timor_leste
# 540           64  ...     0.400000  0.473684  south_central_cross_country_v1
# 640           64  ...     0.729483  0.735069  south_central_cross_country_v2
# 700           64  ...     0.702985  0.734217  south_central_cross_country_v3
# 870           64  ...     0.441935  0.253939  south_central_leave_one_out_v3
# 920           64  ...     0.590625  0.266197  south_central_leave_one_out_v4
# 1040          64  ...     0.451220  0.512111      southeast_cross_country_v1
# 1120          64  ...     0.000000       NaN      southeast_leave_one_out_v1
# 1200          64  ...     0.493827  0.571429       within_country_bangladesh
# 1340          64  ...     0.492537  0.554622            within_country_nepal
# 1440          64  ...     0.419795  0.479532      within_country_philippines
# 1500          64  ...     0.400000  0.487805       within_country_tajikistan
# 1600          64  ...     0.253731  0.369565      within_country_timor_leste
#
#             split_group  max_val_f1  top_n_max_val_f1  \
# 70        leave_one_out    0.603927                 1
# 100       leave_one_out    0.328160                 1
# 220       leave_one_out    0.151220                 1
# 440       leave_one_out    0.486369                 1
# 540   similar geography    0.542373                 1
# 640   similar geography    0.741176                 1
# 700   similar geography    0.737389                 1
# 870   similar geography    0.308571                 1
# 920   similar geography    0.284091                 1
# 1040  similar geography    0.573134                 1
# 1120  similar geography    0.552381                 1
# 1200     within_country    0.628788                 1
# 1340     within_country    0.586751                 1
# 1440     within_country    0.538710                 1
# 1500     within_country    0.561983                 1
# 1600     within_country    0.515152                 1
#
#                              country  data_thresholds  max_val_f1_final  \
# 70                        bangladesh           5k_50d          0.603927
# 100                            nepal           5k_50d          0.328160
# 220                      philippines           5k_50d          0.151220
# 440                      timor_leste           5k_50d          0.486369
# 540   south_central_cross_country_v1           5k_50d          0.542373
# 640   south_central_cross_country_v2           5k_50d          0.741176
# 700   south_central_cross_country_v3           5k_50d          0.737389
# 870                 south_central_v3           5k_50d          0.308571
# 920                 south_central_v4           5k_50d          0.284091
# 1040      southeast_cross_country_v1           5k_50d          0.573134
# 1120                    southeast_v1           5k_50d          0.552381
# 1200                      bangladesh           5k_50d          0.628788
# 1340                           nepal           5k_50d          0.586751
# 1440                     philippines           5k_50d          0.538710
# 1500                      tajikistan           5k_50d          0.561983
# 1600                     timor_leste           5k_50d          0.515152
#
#       best_val_f1
# 70              1
# 100             1
# 220             1
# 440             1
# 540             1
# 640             1
# 700             1
# 870             1
# 920             1
# 1040            1
# 1120            1
# 1200            1
# 1340            1
# 1440            1
# 1500            1
# 1600            1
#
# [16 rows x 51 columns]

# %%
# Save top validation f1 results to s3
joined_subset.to_csv("s3://w210-poverty-mapper/modeling/results/combined_results_top_val_f1.csv", index = False)
